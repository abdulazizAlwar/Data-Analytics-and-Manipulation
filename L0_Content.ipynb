# %% [markdown]
# # Data Analytics & Manipulation Class Schedule

# %% [markdown]
# ### Week 1: Data Toolbox (Fundaments, Pandas, SQL)

# %% [markdown]
# #### Lesson 1: Tables Fundamentals & SQL Basics

# %% [markdown]
# #### Lesson 2: Pandas Fundamentals & Analytics Concpets

# %% [markdown]
# #### Project 1: Data Hands-On
# <br>
# 1. Find any open dataset online and create an SQL Table for it in a Database, in Databricks.
#
# 2. Analyse the data using pandas and write down any findings or intersting things you think you can do with it, For Example:
#   - We can use Linear Regression on this dataset to predict oil price <br>
#   - We can create a dashboard from this dataset to track bird movement <br>
#   - I learned about different kinds of foods <br>
#   - Be creative!
#
# **Resources:**
# You can find a variety of different open datasets from the following sites:
# 1. Dubai Open Data: https://www.dubaipulse.gov.ae/data/category
# 2. UAE Federal Open Data: https://bayanat.ae/
# 3. Kaggle: https://www.kaggle.com/datasets

# %% [markdown]
# ### Week 2: Data Application (Manipulate & Visualize Data)

# %% [markdown]
# ### Week 3: Further Data Application (Manipulate using Spark & Visualize Maps)

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
