# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Read Data

# %%
#If running on Kaggle
# path = "../input/nutrition-facts/menu.csv"

#If Running from repo
path = "./data/menu.csv"

df_original = pd.read_csv(path)

# %%
df = df_original.copy()

# %%
df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
df.columns

# %%
columns = ['Category', 'Item', 'Serving Size', 'Calories',
       'Total Fat', 'Cholesterol',
       'Carbohydrates', 'Dietary Fiber','Sugars', 'Protein',]

df = df[columns]

# %%
df.describe()

# %%
df.info()

# %%
df['Category'].value_counts()

# %% [markdown]
# ## Visualization

# %% [markdown]
# ### All Item Categories

# %% [markdown]
# #### Categorical Columns

# %%
sns.countplot(data=df, y='Category').set_title('Count of items in each category')

# %% [markdown]
# ### Numeric Columns

# %%
sns.displot(data=df, x='Calories')

# %%
sns.displot(data=df, x='Calories', hue='Category', kind='kde')

# %%
sns.boxplot(data=df, x='Calories')

# %%
sns.boxplot(data=df, y='Category', x='Calories')

# %%
sns.scatterplot(data=df, x='Calories', y='Protein')

# %%
sns.scatterplot(data=df, x='Calories', y='Protein', hue='Category')

# %% [markdown]
# ## Sandwiches

# %%
df['Category'].unique()

# %%
categories = ['Breakfast', 'Beef & Pork', 'Chicken & Fish']

df = df.loc[df['Category'].isin(categories)]

# %%
df.head()

# %% [markdown]
# #### Categorical Columns

# %%
sns.countplot(data=df, y='Category')

# %% [markdown]
# ### Numeric Columns

# %%
sns.displot(data=df, x='Calories')

# %%
sns.displot(data=df, x='Calories', hue='Category', kind='kde')

# %%
sns.boxplot(data=df, x='Calories')

# %%
sns.boxplot(data=df, y='Category', x='Calories')

# %%
sns.scatterplot(data=df, x='Calories', y='Protein')

# %%
sns.scatterplot(data=df, x='Calories', y='Protein', hue='Category')

# %% [markdown]
# ## Drinks

# %%
df_original['Category'].unique()

# %%
df = df_original.copy()

# %%
categories = ['Beverages', 'Coffee & Tea', 'Smoothies & Shakes']

df = df.loc[df['Category'].isin(categories)]

# %%
df.head()

# %% [markdown]
# #### Categorical Columns

# %%
sns.countplot(data=df, y='Category')

# %% [markdown]
# ### Numeric Columns

# %%
sns.displot(data=df, x='Calories')

# %%
sns.displot(data=df, x='Calories', hue='Category', kind='kde')

# %%
sns.boxplot(data=df, x='Calories')

# %%
sns.boxplot(data=df, y='Category', x='Calories')

# %%
sns.scatterplot(data=df, x='Calories', y='Protein')

# %%
sns.scatterplot(data=df, x='Calories', y='Protein', hue='Category')
