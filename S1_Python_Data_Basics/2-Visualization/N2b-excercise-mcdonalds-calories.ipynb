# %% [markdown]
# # Data Visualization Exercise
#
# Solve each question by filling the `_` with the correct code

# %%
#Sample Question - Add the value of variable x to the value of variable y in the variable z and print the output

x = 3
y = 5

z = _ + _

__(z)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-7b5a36e26dda> in <module>
#       6 z = _ + _
#       7
# ----> 8 __(z)
#
# TypeError: 'str' object is not callable

# %%
#Solution

x = 3
y = 5

z = x + y

print(z)
# Out:
# 8

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Read Data

# %%
#If running on Kaggle
# path = "../input/nutrition-facts/menu.csv"

#If Running from repo
path = "./data/menu.csv"

df_original = pd.read_csv(path)

# %%
#Create a copy of the dataframe that can be re-read later
df = df_original.copy()

# %%
df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
df.columns
# Out:
# Index(['Category', 'Item', 'Serving Size', 'Calories', 'Calories from Fat',
#        'Total Fat', 'Total Fat (% Daily Value)', 'Saturated Fat',
#        'Saturated Fat (% Daily Value)', 'Trans Fat', 'Cholesterol',
#        'Cholesterol (% Daily Value)', 'Sodium', 'Sodium (% Daily Value)',
#        'Carbohydrates', 'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#        'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#        'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#        'Calcium (% Daily Value)', 'Iron (% Daily Value)'],
#       dtype='object')

# %%
columns = ['Category', 'Item', 'Serving Size', 'Calories',
       'Total Fat', 'Cholesterol',
       'Carbohydrates', 'Dietary Fiber','Sugars', 'Protein',]

df = df[columns]

# %%
df.describe()

# %%
df.info()

# %%
df['Category'].value_counts()

# %% [markdown]
# ## Visualization

# %% [markdown]
# ### All Categories

# %% [markdown]
# #### Categorical Columns

# %% [markdown]
# ##### Countplot

# %%
#Q1 - Plot the count of each item in the column "Category"
sns.__(data=_, x=_)

# %% [markdown]
# ### Numeric Columns

# %% [markdown]
# ##### Distribution Plot

# %%
#Q2A - Plot the distribution plot of the column 'Calories'

sns.___

# %%
#Q2B - Plot the distribution plot of the column 'Calories' and use the 'Category' column as a hue


sns.___

# %%
#Q2C - Plot the KDE distribution plot of the above


sns.___

# %% [markdown]
# ##### Boxplot

# %%
#Q3A - Plot a box plot of the column 'Calories'

sns.___

# %%
#Q3B - Plot a box plot of the column 'Calories' on the y-axis and 'Category' on the x-axis

sns.___

# %% [markdown]
# ##### Scatterplot

# %%
#Q4A - Plot a scatter plot of the columns 'Calories' & 'Protein'

sns.___

# %%
#Q4A - Plot a scatter plot of the columns 'Calories' & 'Protein' and use the column 'Category' as hue

sns.___

# %% [markdown]
# ## Sandwiches
#
# Run the above plots on categories that are considered a sandwich

# %%
df['Category'].unique()

# %%
categories = ['Breakfast', 'Beef & Pork', 'Chicken & Fish']

df = df.loc[df['Category'].isin(categories)]

# %%
df.head()

# %% [markdown]
# ### Repeat the above visualizations for the sandwitch type items only

# %% [markdown]
# ## Drinks

# %%
df_original['Category'].unique()

# %%
df = df_original.copy()

# %%
categories = ['Beverages', 'Coffee & Tea', 'Smoothies & Shakes']

df = df.loc[df['Category'].isin(categories)]

# %%
df.head()

# %% [markdown]
# ### Repeat the above visualizations for the drink type items only
