# %% [markdown]
# # Introduction to Pandas

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np

# %%
pd.__version__

# %% [markdown]
# ### Read CSV File to Dataframe

# %%
#If running on Kaggle
# path = "../input/titanic/train.csv"

#If Running anywhere else
path = "https://github.com/datasciencedojo/datasets/raw/master/titanic.csv"

df = pd.read_csv(path)

# %% [markdown]
# ### Looking at Data

# %%
df.head()

# %%
df.head(20)

# %%
df.tail()

# %%
import seaborn as sns

# %%
sns.displot(data=df, x='Sex', hue='Survived')

# %% [markdown]
# ### Basic Dataframe Statistics

# %%
df.shape

# %%
df.info()

# %%
df.describe()

# %%
df.describe(include=np.object)

# %%
df.columns

# %% [markdown]
# ### Selecting Data in Dataframe

# %%
df['Ticket']

# %%
df[['Ticket']]

# %%
columns = ['Ticket']
df[columns]

# %%
df['Sex'].value_counts()

# %%
df['Sex'].unique()

# %%
df['Age'].max()

# %%
df['Age'].median()

# %%
gender_counts = pd.DataFrame(df['Sex'].value_counts())
gender_counts

# %% [markdown]
# ### Visualize Data

# %%
df['Age'].plot()

# %%
gender_counts.plot(kind='bar')

# %%
df.plot(kind='scatter', x='Age', y='Fare')
